# %%
import pandas as pd

# %%
print("Hello word")
# Out:
# Hello word

# %%
data=pd.Series([1,2,3])
print(data)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
df=pd.read_csv(r"C:/Users/AKRE/Downloads/students.csv"
# Out:
#   Cell In[13], line 1
#     df=pd.read_csv("C:/Users/AKRE/Documents/FORMATION/FORMATION TTA/DI-Bootcamp-TTA/Week2/Day1/Course/students.csv"
#                                                                                                                    ^
# _IncompleteInputError: incomplete input
