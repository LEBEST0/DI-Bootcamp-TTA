# %%
import pandas as pd

# %%
# !pip install google

# %%
# !pip install kaggle
# Out:
# ...
#
#    ------------- -------------------------- 2/6 [protobuf]
#    ------------- -------------------------- 2/6 [protobuf]
#    ------------- -------------------------- 2/6 [protobuf]
#    -------------------- ------------------- 3/6 [kagglesdk]
#    -------------------- ------------------- 3/6 [kagglesdk]
#    -------------------- ------------------- 3/6 [kagglesdk]
#    -------------------- ------------------- 3/6 [kagglesdk]
#    -------------------- ------------------- 3/6 [kagglesdk]
#    -------------------- ------------------- 3/6 [kagglesdk]
#    -------------------- ------------------- 3/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [jupytext]
#    -------------------------- ------------- 4/6 [jupytext]
#    -------------------------- ------------- 4/6 [jupytext]
#    --------------------------------- ------ 5/6 [kaggle]
#    ---------------------------------------- 6/6 [kaggle]
#
# ...

# %%
import os
import shutil

os.makedirs(
    os.path.expanduser("~/.kaggle"),
    exist_ok=True
)

shutil.copy(
    "kaggle.json",
    os.path.expanduser(
        "~/.kaggle/kaggle.json"
    )
)

print("Kaggle configuré")
# Out:
# Kaggle configuré

# %%
# !kaggle datasets download -d olgabelitskaya/flower-color-images
# Out:
# Dataset URL: https://www.kaggle.com/datasets/olgabelitskaya/flower-color-images
# License(s): other
# ...
#   0%|          | 0.00/50.1M [00:00<?, ?B/s]
#   2%|1         | 1.00M/50.1M [00:02<01:45, 489kB/s]
#   4%|3         | 2.00M/50.1M [00:03<01:23, 602kB/s]
#   6%|5         | 3.00M/50.1M [00:04<01:09, 712kB/s]
#   8%|7         | 4.00M/50.1M [00:05<00:55, 871kB/s]
#  10%|9         | 5.00M/50.1M [00:06<00:43, 1.08MB/s]
#  12%|#1        | 6.00M/50.1M [00:06<00:32, 1.40MB/s]
#  14%|#3        | 7.00M/50.1M [00:06<00:29, 1.54MB/s]
#  16%|#5        | 8.00M/50.1M [00:07<00:20, 2.11MB/s]
#  18%|#7        | 9.00M/50.1M [00:07<00:20, 2.07MB/s]
#  20%|#9        | 10.0M/50.1M [00:07<00:17, 2.37MB/s]
#  22%|##1       | 11.0M/50.1M [00:08<00:15, 2.59MB/s]
#  24%|##3       | 12.0M/50.1M [00:08<00:14, 2.80MB/s]
#  26%|##5       | 13.0M/50.1M [00:09<00:16, 2.42MB/s]
#  28%|##7       | 14.0M/50.1M [00:09<00:13, 2.76MB/s]
#  30%|##9       | 15.0M/50.1M [00:10<00:17, 2.04MB/s]
# ...

# %%
import zipfile

with zipfile.ZipFile(r"C:\Users\AKRE\Documents\FORMATION\FORMATION TTA\DI-Bootcamp-TTA\Week2\Day1\daily-challenge\flower-color-images.zip", 'r') as zip_ref:
    zip_ref.extractall("dossier_extrait")

# %%
# !pip install tensorflow
! pip install keras
! pip install pillow

# %%
# !pip install matplotlib pillow
# Out:
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# ...
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    ------ --------------------------------- 1.3/8.2 MB 6.9 MB/s eta 0:00:02
#    -------------- ------------------------- 2.9/8.2 MB 6.9 MB/s eta 0:00:01
#    ------------------- -------------------- 3.9/8.2 MB 6.4 MB/s eta 0:00:01
#    ------------------------- -------------- 5.2/8.2 MB 6.4 MB/s eta 0:00:01
#    ------------------------------- -------- 6.6/8.2 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  8.1/8.2 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------------- 8.2/8.2 MB 6.0 MB/s eta 0:00:00
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------- ----------------- 1.3/2.3 MB 7.4 MB/s eta 0:00:01
# ...

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Load image
image_path = r"C:\Users\AKRE\Documents\FORMATION\FORMATION TTA\DI-Bootcamp-TTA\Week2\Day1\daily-challenge\dossier_extrait\flowers\flowers\00_002.png"
original_image = Image.open(image_path)

# Display image
plt.imshow(original_image)
plt.axis('off')
plt.show()

# %%
from scipy.ndimage import rotate
def rotate_image_30_degrees(image):
  return rotate(image,30,reshape=True) #complete it

# %%
image=r"C:\Users\AKRE\Documents\FORMATION\FORMATION TTA\DI-Bootcamp-TTA\Week2\Day1\daily-challenge\dossier_extrait\flowers\flowers\00_002.png"
my_image=Image.open(image)
image_array=np.array(my_image)
rotated_image=rotate_image_30_degrees(image_array)

plt.imshow(rotated_image)

# %%
import pandas as pd
url=r"https://github.com/devtlv/Datasets-DA-Bootcamp-2-/raw/refs/heads/main/Week%204%20-%20Data%20Understanding/W4D2%20-%20Data%20U.%20and%20pre-processing/Iris%20Dataset.zip"
my_data=pd.read_csv(url,compression="zip")

my_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
my_data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df = pd.DataFrame({
    "Age": [25, 25, 25, 40],
    "Salary": [25, 25, 25, 40],
    "Score": [25, 25, 25, np.nan]
})
print(df)
print(df.isnull())
# Out:
#    Age  Salary  Score
# 0   25      25   25.0
# 1   25      25   25.0
# 2   25      25   25.0
# 3   40      40    NaN
#      Age  Salary  Score
# 0  False   False  False
# 1  False   False  False
# 2  False   False  False
# 3  False   False   True

# %%
df_cleaned = df.dropna()

# %%
df_cleaned
# Out:
#    Age  Salary  Score
# 0   25      25   25.0
# 1   25      25   25.0
# 2   25      25   25.0

# %%
df_clean = df.drop_duplicates()

# %%
df_clean
# Out:
#    Age  Salary  Score
# 0   25      25   25.0
# 3   40      40    NaN
